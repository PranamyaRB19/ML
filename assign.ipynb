# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.5.3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data = pd.read_csv("/content/drive/MyDrive/Studentdetails.csv")
print(data.to_string())
print("Mean:")
print(data.mean())
print("\nMedian")
print(data.median())
data.plot()
plt.show()
# Out:
#   Name  CGPA  Credits
# 0    A  9.50      100
# 1    B  8.70      100
# 2    C  4.60       96
# 3    D  6.80       96
# 4    E  7.17      100
# 5    F  8.10      100
# 6    G  9.20      100
# 7    H  4.80       94
# 8    I  6.40       96
# 9    J  4.90       90
# Mean:
# CGPA        7.017
# Credits    97.200
# dtype: float64
#
# Median
# CGPA        6.985
# Credits    98.000
# dtype: float64
# <ipython-input-3-e0bbd6947a29>:7: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(data.mean())
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoint=(["Banglore","Hyderabad","Mumbai","Chennai"])
ypoint=([13607800,10801163,25368000,11933000])
c=(["red","blue","green","hotpink"])
plt.bar(xpoint,ypoint,color=["red","blue","hotpink","yellow"])
plt.xlabel("City")
plt.ylabel("Population")
plt.show()

# %%
import random
import matplotlib.pyplot as plt
comp_score=0
user_score=0
tie=0
for x in range(5):
  comp=random.randint(1,99)
  user=int(input(("Enter numbet between 1 to 99 ")))
  if (comp>user):
    comp_score+=1
  elif (user>comp):
    user_score+=1
  else:
    tie+=1
print("computer points")
print(comp_score)
print("user points")
print(user_score)
if(comp_score>user_score):
  print("Computer  won")
else:
  print("User won")
x=(["Computer","User","Tie"])
y=([comp_score,user_score,tie])
plt.bar(x,y)
plt.ylabel("Score")
plt.show()
# Out:
# Enter numbet between 1 to 99 45
# Enter numbet between 1 to 99 48
# Enter numbet between 1 to 99 98
# Enter numbet between 1 to 99 57
# Enter numbet between 1 to 99 79
# computer points
# 1
# user points
# 4
# User won
