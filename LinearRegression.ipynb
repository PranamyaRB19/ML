# %% [markdown]
# #Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
x = np.array([1,5,13,25,33,46]).reshape((-1,1))
y = np.array([3,6,15,12,21,18])
plt.scatter(x,y)
plt.xlabel("Independent Variable")
plt.ylabel("Dependent Variable")
from sklearn.linear_model import LinearRegression
SLR = LinearRegression()
SLR.fit(x,y)
pred = SLR.predict(x)
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y,pred)
plt.plot(x,pred,color='hotpink',marker='o')
print("Mean Square Error : ",mse)
print("Intercept : ",SLR.intercept_)
print("Slope : ",SLR.coef_)
plt.show()
# Out:
# Mean Square Error :  11.247422680412372
# Intercept :  5.525773195876288
# Slope :  [0.34020619]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
x1=[]
y1=[]
for i in range(0,6):
  x1.append(random.randint(1,99))
  y1.append(random.randint(1,99))
x = np.array([x1[0],x1[1],x1[2],x1[3],x1[4],x1[5]]).reshape((-1,1))
y = np.array([y1[0],y1[1],y1[2],y1[3],y1[4],y1[5]])
plt.scatter(x,y)
plt.xlabel("Independent Variable")
plt.ylabel("Dependent Variable")
from sklearn.linear_model import LinearRegression
SLR = LinearRegression()
SLR.fit(x,y)
pred = SLR.predict(x)
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y,pred)
plt.plot(x,pred,color='hotpink',marker='o')
print("Mean Square Error : ",mse)
print("Intercept : ",SLR.intercept_)
print("Slope : ",SLR.coef_)
plt.show()
# Out:
# Mean Square Error :  538.0470313793363
# Intercept :  10.185040258860724
# Slope :  [0.61328919]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
x1=[]
y1=[]
data = pd.read_csv('/content/drive/MyDrive/Studentdetails.csv')
x1 = data['CGPA'].values.tolist()
y1 = data['Credits'].values.tolist()
x = np.array([x1[0],x1[1],x1[2],x1[3],x1[4],x1[5]]).reshape((-1,1))
y = np.array([y1[0],y1[1],y1[2],y1[3],y1[4],y1[5]])
plt.scatter(x,y)
plt.xlabel("Independent Variable")
plt.ylabel("Dependent Variable")
from sklearn.linear_model import LinearRegression
SLR = LinearRegression()
SLR.fit(x,y)
pred = SLR.predict(x)
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y,pred)
plt.plot(x,pred,color='hotpink',marker='o')
print("Mean Square Error : ",mse)
print("Intercept : ",SLR.intercept_)
print("Slope : ",SLR.coef_)
plt.show()
# Out:
# Mean Square Error :  1.2772347702427116
# Intercept :  91.48098810736579
# Slope :  [0.96086631]
